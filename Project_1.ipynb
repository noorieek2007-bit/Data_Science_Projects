# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Latest Covid-19 India Status.csv')
display(data)
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/Latest Covid-19 India Status.csv')
df=pd.DataFrame(data)
display(df.drop(["Total Cases", "Active","Discharged","Discharge Ratio","Active Ratio","Population",],axis=1))
# Out:
#                                    State/UTs  Deaths  Death Ratio
# 0                        Andaman and Nicobar     129         1.20
# 1                             Andhra Pradesh   14733         0.63
# 2                          Arunachal Pradesh     296         0.44
# 3                                      Assam    8035         1.08
# 4                                      Bihar   12314         1.44
# 5                                 Chandigarh    1185         1.18
# 6                               Chhattisgarh   14190         1.19
# 7   Dadra and Nagar Haveli and Daman and Diu       4         0.03
# 8                                      Delhi   26666         1.31
# 9                                        Goa    4014         1.52
# 10                                   Gujarat   11079         0.86
# 11                                   Haryana   10755         1.00
# 12                          Himachal Pradesh    4241         1.31
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/Latest Covid-19 India Status.csv')
Recovery=pd.DataFrame(data)
display(Recovery.drop(["Total Cases", "Active","Deaths","Death Ratio","Active Ratio","Population",],axis=1))
# Out:
#                                    State/UTs  Discharged  Discharge Ratio
# 0                        Andaman and Nicobar       10637            98.80
# 1                             Andhra Pradesh     2325943            99.37
# 2                          Arunachal Pradesh       66753            99.56
# 3                                      Assam      738119            98.92
# 4                                      Bihar      842952            98.56
# 5                                 Chandigarh       99508            98.82
# 6                               Chhattisgarh     1173505            98.81
# 7   Dadra and Nagar Haveli and Daman and Diu       11588            99.97
# 8                                      Delhi     2014230            98.69
# 9                                        Goa      259329            98.47
# 10                                   Gujarat     1280299            99.14
# 11                                   Haryana     1068121            99.00
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/covid-19-daily-cases-data.csv')

Daily_Cases=pd.DataFrame(data)
display(Daily_Cases.drop(["units", "notes",],axis=1))
# Out:
#       data_as_on                category     value
# 0     10-06-2024    Total Positive Cases  45040074
# 1     10-06-2024  Number of Active cases       206
# 2     10-06-2024         Total Recovered  44506249
# 3     10-06-2024            Total Deaths    533619
# 4     09-06-2024    Total Positive Cases  45040060
# ...          ...                     ...       ...
# 6275  25-03-2020            Total Deaths        10
# 6276  24-03-2020    Total Positive Cases       536
# 6277  24-03-2020  Number of Active cases       487
# 6278  24-03-2020         Total Recovered        39
# 6279  24-03-2020            Total Deaths        10
#
# [6280 rows x 3 columns]
